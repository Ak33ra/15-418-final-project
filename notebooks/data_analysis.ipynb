# %%
# %%capture
# %run ./analysis.ipynb

# %% [markdown]
# ## Baseline Tests

# %%
solo_gpt2 = DataAnalyzer()
solo_gpt2.load_files("../data/solo_distilgpt2_b8_128/distilgpt2/events.jsonl", dataset_name="solo_gpt2")

solo_gpt2.add_throughput_column(latency_column = 'latency_ms')

solo_gpt2.plot_distributions(column='latency_ms', plot_type='both', bins=10)
print(solo_gpt2.compute_statistics(column='latency_ms'))
solo_gpt2.list_datasets()
solo_gpt2.get_gpu_cpu_runtime(dataset_name='solo_gpt2')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'solo_gpt2'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#      dataset      column  count      mean      std       min       max  \
# 0  solo_gpt2  latency_ms    103  4.988744  0.91174  4.502528  8.904704
#
#         p50       p90       p95       p99
# 0  4.652544  5.403853  7.703091  8.542792
# {'total_gpu_time_ms': 498.8743677139282,
#  'total_cpu_time_ms': 31.06663349457085,
#  'total_wall_time_ms': 529.9410012084991,
#  'num_iterations': 100,
#  'gpu_utilization_pct': 94.13771845852176,
#  'avg_gpu_time_per_iter_ms': 4.988743677139282,
#  'avg_cpu_overhead_per_iter_ms': 0.3106663349457085}

# %%
solo_bert = DataAnalyzer()
solo_bert.load_files("../data/solo_distilBERT/distilbert/events.jsonl", dataset_name="solo_bert")

solo_bert.add_throughput_column(latency_column = 'latency_ms')

solo_bert.plot_distributions(column='latency_ms', plot_type='both', bins=10)
solo_bert.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'solo_bert'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#      dataset      column  count      mean       std       min       max  \
# 0  solo_bert  latency_ms    103  2.904228  0.504401  2.578432  5.363712
#
#         p50       p90       p95       p99
# 0  2.722816  3.467674  4.271309  4.640901

# %%
solo_llama = DataAnalyzer()
solo_llama.load_files("../data/solo_llama/llama/events.jsonl", dataset_name="solo_llama")

solo_llama.add_throughput_column(latency_column = 'latency_ms')

solo_llama.plot_distributions(column='latency_ms', plot_type='both', bins=10)
solo_llama.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'solo_llama'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#       dataset      column  count      mean        std        min         max  \
# 0  solo_llama  latency_ms    103  51.28362  13.394886  43.192322  103.770111
#
#          p50        p90        p95        p99
# 0  46.151169  70.251829  83.359591  99.306523

# %%
solo_mistral = DataAnalyzer()
solo_mistral.load_files("../data/solo_mistral7b/mistral7b/events.jsonl", dataset_name="solo_mistral")

solo_mistral.add_throughput_column(latency_column = 'latency_ms')

solo_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=10)
solo_mistral.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'solo_mistral'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#         dataset      column  count        mean        std        min  \
# 0  solo_mistral  latency_ms    103  102.925189  19.457756  90.569725
#
#           max        p50         p90         p95        p99
# 0  158.964737  93.029888  143.572987  147.534431  152.96327

# %%
solo_roberta = DataAnalyzer()
solo_roberta.load_files("../data/solo_RoBERTa/RoBERTa/events.jsonl", dataset_name="solo_roberta")

solo_roberta.add_throughput_column(latency_column = 'latency_ms')

solo_roberta.plot_distributions(column='latency_ms', plot_type='both', bins=10)
solo_roberta.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'solo_roberta'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#         dataset      column  count       mean       std        min        max  \
# 0  solo_roberta  latency_ms    103  12.089303  2.229542  11.177984  31.079424
#
#          p50        p90        p95       p99
# 0  11.469824  14.215271  15.329075  17.05304

# %% [markdown]
# ## Pair Tests

# %%
pair_bert = DataAnalyzer()
pair_bert.load_pattern("../data/pair_distilbert/**/events.jsonl", label_extractor= lambda name : name.parent.name)

pair_bert.add_throughput_column(latency_column = 'latency_ms')

pair_bert.plot_distributions(column='latency_ms', plot_type='both', bins=10)
pair_bert.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilbert_1'
# Added 'throughput' column to dataset 'distilbert_2'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#         dataset      column  count      mean       std       min       max  \
# 0  distilbert_1  latency_ms    103  3.190856  0.169803  2.992128  4.233216
# ...

# %%
pair_llama = DataAnalyzer()
pair_llama.load_pattern("../data/pair_llama/**/events.jsonl", label_extractor= lambda name : name.parent.name)

pair_llama.add_throughput_column(latency_column = 'latency_ms')

pair_llama.plot_distributions(column='latency_ms', plot_type='both', bins=10)
pair_llama.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'llama3.2_3b_2'
# Added 'throughput' column to dataset 'llama3.2_3b_1'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#          dataset      column  count       mean       std        min  \
# 0  llama3.2_3b_2  latency_ms    103  91.861197  1.422340  87.892990
# 1  llama3.2_3b_1  latency_ms    103  92.029962  1.901823  78.579712
#
# ...

# %%
pair_mistral = DataAnalyzer()
pair_mistral.load_pattern("../data/pair_mistral7b/**/events.jsonl", label_extractor= lambda name : name.parent.name)

pair_mistral.add_throughput_column(latency_column = 'latency_ms')

pair_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=10)
pair_mistral.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'mistral7b_1'
# Added 'throughput' column to dataset 'mistral7b_2'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#        dataset      column  count        mean       std         min  \
# 0  mistral7b_1  latency_ms    103  187.456113  1.835808  184.321030
# 1  mistral7b_2  latency_ms    103  187.702098  3.506853  159.635452
#
# ...

# %%
pair_roberta = DataAnalyzer()
pair_roberta.load_pattern("../data/pair_roberta/**/events.jsonl", label_extractor= lambda name : name.parent.name)

pair_roberta.add_throughput_column(latency_column = 'latency_ms')

pair_roberta.plot_distributions(column='latency_ms', plot_type='both', bins=10)
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'roberta_1'
# Added 'throughput' column to dataset 'roberta_2'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024

# %%
pair_gpt2 = DataAnalyzer()
pair_gpt2.load_pattern("../data/mps_pair_distilGPT2/**/events.jsonl", label_extractor= lambda name : name.parent.name)

pair_gpt2.add_throughput_column(latency_column = 'latency_ms')

pair_gpt2.plot_distributions(column='latency_ms', plot_type='both', bins=10)
print(pair_gpt2.compute_statistics(column='latency_ms'))
print(pair_gpt2.get_gpu_cpu_runtime(dataset_name='distilgpt2_1'))
print(pair_gpt2.get_gpu_cpu_runtime(dataset_name='distilgpt2_2'))

compute_fairness_metrics(pair_gpt2, column='latency_ms', metric='median')
test_statistical_significance(pair_gpt2)
analyze_gpu_kernel_execution('../out/nsys/mps_pair_distilGPT2', analyzer=pair_gpt2)
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilgpt2_1'
# Added 'throughput' column to dataset 'distilgpt2_2'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
#         dataset      column  count      mean       std       min       max  \
# 0  distilgpt2_1  latency_ms    103  6.544384  0.479256  5.041152  8.119296
# ...

# %% [markdown]
# ## Encoder Only

# %%
bert_roberta = DataAnalyzer()
bert_roberta.load_pattern("../data/bert_roberta/**/events.jsonl", label_extractor= lambda name : name.parent.name)

bert_roberta.add_throughput_column(latency_column = 'latency_ms')

bert_roberta.plot_distributions(column='latency_ms', plot_type='both', bins=10)
bert_roberta.compute_statistics(column='latency_ms')
detect_resource_hogging_normalized(bert_roberta, [solo_bert, solo_roberta])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'roberta_large'
# Added 'throughput' column to dataset 'distilbert'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# NORMALIZED RESOURCE HOGGING DETECTION (Baseline-Aware)
# ...
# This analysis accounts for different baseline performance of different models.
# Column: latency_ms
# Hogging threshold: 15.0% difference in relative slowdown
# ...

# %% [markdown]
# ## Decoder Only

# %%
llama_2_mistral_1 = DataAnalyzer()
llama_2_mistral_1.load_pattern("../data/2_llama_1_mistral/**/events.jsonl", label_extractor= lambda name : name.parent.name)

llama_2_mistral_1.add_throughput_column(latency_column = 'latency_ms')

llama_2_mistral_1.plot_distributions(column='latency_ms', plot_type='both', bins=30)
detect_resource_hogging_normalized(llama_2_mistral_1, [solo_llama, solo_mistral])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'llama3.2_3b_2'
# Added 'throughput' column to dataset 'llama3.2_3b_1'
# ...

# %%
gpt2_mistral = DataAnalyzer()
gpt2_mistral.load_pattern("../data/distilGPT2_mistral7b/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_mistral.add_throughput_column(latency_column = 'latency_ms')

gpt2_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=15)
gpt2_mistral.compute_statistics(column='latency_ms')
detect_resource_hogging_normalized(gpt2_mistral, [solo_gpt2, solo_mistral])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilgpt2'
# Added 'throughput' column to dataset 'mistral7b'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# NORMALIZED RESOURCE HOGGING DETECTION (Baseline-Aware)
# ...
# This analysis accounts for different baseline performance of different models.
# Column: latency_ms
# Hogging threshold: 15.0% difference in relative slowdown
# ...

# %%
gpt2_3_mistral = DataAnalyzer()
gpt2_3_mistral.load_pattern("../data/3_distilgpt2_mistral7b/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_3_mistral.add_throughput_column(latency_column = 'latency_ms')

gpt2_3_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=30)
detect_resource_hogging_normalized(gpt2_3_mistral, [solo_gpt2, solo_mistral])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
gpt2_3 = DataAnalyzer()
gpt2_3.load_pattern("../data/3_distilgpt2_mps/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_3.add_throughput_column(latency_column = 'latency_ms')

gpt2_3.plot_distributions(column='latency_ms', plot_type='both', bins=50)
gpt2_3.compute_statistics(column='latency_ms')
detect_resource_hogging_normalized(gpt2_3, [solo_gpt2])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilgpt2_1'
# Added 'throughput' column to dataset 'distilgpt2_2'
# ...

# %%
gpt2_4 = DataAnalyzer()
gpt2_4.load_pattern("../data/4_distilgpt2_mps/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_4.add_throughput_column(latency_column = 'latency_ms')

gpt2_4.plot_distributions(column='latency_ms', plot_type='both', bins=15)
gpt2_4.compute_statistics(column="latency_ms")
detect_resource_hogging_normalized(gpt2_4, [solo_gpt2])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
gpt2_10 = DataAnalyzer()
gpt2_10.load_pattern("../data/10_distilgpt2/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_10.add_throughput_column(latency_column = 'latency_ms')

gpt2_10.plot_distributions(column='latency_ms', plot_type='both', bins=15)
gpt2_10.compute_statistics(column='latency_ms')
detect_resource_hogging_normalized(gpt2_10, [solo_gpt2])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
compute_fairness_metrics(gpt2_10)
detect_resource_hogging_normalized(gpt2_10, solo_gpt2)
# Out:
# ...
# FAIRNESS ANALYSIS: latency_ms (using mean)
# ...
# Number of models: 10
#
# Individual means:
#   distilgpt2_8        :    28.17 (+4.81% from avg)
#   distilgpt2_1        :    27.36 (+1.81% from avg)
#   distilgpt2_6        :    26.57 (-1.14% from avg)
#   distilgpt2_7        :    28.57 (+6.30% from avg)
#   distilgpt2_9        :    27.82 (+3.50% from avg)
#   distilgpt2_10       :    27.77 (+3.31% from avg)
#   distilgpt2_5        :    26.16 (-2.67% from avg)
#   distilgpt2_2        :    23.64 (-12.03% from avg)
#   distilgpt2_3        :    26.96 (+0.32% from avg)
#   distilgpt2_4        :    25.75 (-4.21% from avg)
#
# ────────────────────────────────────────────────────────────────────────────────
# MANN-WHITNEY U TESTS (Pairwise Median Comparisons)
# ────────────────────────────────────────────────────────────────────────────────
# Tests whether the medians of two groups are significantly different.
# More robust to outliers than t-tests.
#
# ...

# %%
llama_3 = DataAnalyzer()
llama_3.load_pattern("../data/3_llama/**/events.jsonl", label_extractor= lambda name : name.parent.name)

llama_3.add_throughput_column(latency_column = 'latency_ms')

llama_3.plot_distributions(column='latency_ms', plot_type='both', bins=15)
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'llama3.2_3b_2'
# Added 'throughput' column to dataset 'llama3.2_3b_3'
# ...

# %%
gpt2_5_llama = DataAnalyzer()
gpt2_5_llama.load_pattern("../data/5_distilgpt2_llama/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_5_llama.add_throughput_column(latency_column = 'latency_ms')

gpt2_5_llama.plot_distributions(column='latency_ms', plot_type='both', bins=15)
gpt2_5_llama.compute_statistics(column='latency_ms')
detect_resource_hogging_normalized(gpt2_5_llama, [solo_gpt2, solo_llama])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
llama_mistral = DataAnalyzer()
llama_mistral.load_pattern("../data/llama_mistral7b/**/events.jsonl", label_extractor= lambda name : name.parent.name)

llama_mistral.add_throughput_column(latency_column = 'latency_ms')

llama_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=15)
detect_resource_hogging_normalized(llama_mistral, [solo_llama, solo_mistral])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'llama3.2_3b'
# Added 'throughput' column to dataset 'mistral7b'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# NORMALIZED RESOURCE HOGGING DETECTION (Baseline-Aware)
# ...
# This analysis accounts for different baseline performance of different models.
# Column: latency_ms
# Hogging threshold: 15.0% difference in relative slowdown
# ...

# %%
gpt2_llama_mistral = DataAnalyzer()
gpt2_llama_mistral.load_pattern("../data/mistral_llama_distilgpt2/**/events.jsonl", label_extractor= lambda name : name.parent.name)

gpt2_llama_mistral.add_throughput_column(latency_column = 'latency_ms')

gpt2_llama_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=15)
detect_resource_hogging_normalized(gpt2_llama_mistral, [solo_gpt2, solo_llama, solo_mistral])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'llama3.2_3b'
# Added 'throughput' column to dataset 'distilgpt2'
# ...

# %% [markdown]
# ## Combination of Encoder and Decoder

# %%
roberta_3_llama = DataAnalyzer()
roberta_3_llama.load_pattern("../data/3_roberta_1_llama/**/events.jsonl", label_extractor= lambda name : name.parent.name)

roberta_3_llama.add_throughput_column(latency_column = 'latency_ms')

roberta_3_llama.plot_distributions(column='latency_ms', plot_type='both', bins=15)
detect_resource_hogging_normalized(roberta_3_llama, [solo_roberta, solo_llama])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
roberta_3_gpt2_2 = DataAnalyzer()
roberta_3_gpt2_2.load_pattern("../data/3_roberta_2_distilgpt2/**/events.jsonl", label_extractor= lambda name : name.parent.name)

roberta_3_gpt2_2.add_throughput_column(latency_column = 'latency_ms')

roberta_3_gpt2_2.plot_distributions(column='latency_ms', plot_type='both', bins=15)
detect_resource_hogging_normalized(roberta_3_gpt2_2, [solo_roberta, solo_gpt2])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
bert_4_mistral = DataAnalyzer()
bert_4_mistral.load_pattern("../data/4_distilbert_1_mistral/**/events.jsonl", label_extractor= lambda name : name.parent.name)

bert_4_mistral.add_throughput_column(latency_column = 'latency_ms')

bert_4_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=15)
detect_resource_hogging_normalized(bert_4_mistral, [solo_bert, solo_mistral])
bert_4_mistral.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
all_models = DataAnalyzer()
all_models.load_pattern("../data/all_models/**/events.jsonl", label_extractor= lambda name : name.parent.name)

all_models.add_throughput_column(latency_column = 'latency_ms')

all_models.plot_distributions(column='latency_ms', plot_type='both', bins=15)
detect_resource_hogging_normalized(all_models, [solo_bert, solo_roberta, solo_gpt2, solo_llama, solo_mistral])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# ...

# %%
bert_gpt2 = DataAnalyzer()
bert_gpt2.load_pattern("../data/distilbert_gpt2/**/events.jsonl", label_extractor= lambda name : name.parent.name)

bert_gpt2.add_throughput_column(latency_column = 'latency_ms')

bert_gpt2.plot_distributions(column='latency_ms', plot_type='both', bins=15)
bert_gpt2.compute_statistics(column="latency_ms")
detect_resource_hogging_normalized(bert_gpt2, [solo_bert, solo_gpt2])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilgpt2'
# Added 'throughput' column to dataset 'distilbert'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# NORMALIZED RESOURCE HOGGING DETECTION (Baseline-Aware)
# ...
# This analysis accounts for different baseline performance of different models.
# Column: latency_ms
# Hogging threshold: 15.0% difference in relative slowdown
# ...

# %%
bert_llama = DataAnalyzer()
bert_llama.load_pattern("../data/distilbert_llama/**/events.jsonl", label_extractor= lambda name : name.parent.name)

bert_llama.add_throughput_column(latency_column = 'latency_ms')

bert_llama.plot_distributions(column='latency_ms', plot_type='both', bins=15)
bert_llama.compute_statistics(column="latency_ms")
detect_resource_hogging_normalized(bert_llama, [solo_bert, solo_llama])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'llama3.2_3b'
# Added 'throughput' column to dataset 'distilbert'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# NORMALIZED RESOURCE HOGGING DETECTION (Baseline-Aware)
# ...
# This analysis accounts for different baseline performance of different models.
# Column: latency_ms
# Hogging threshold: 15.0% difference in relative slowdown
# ...

# %%
bert_mistral = DataAnalyzer()
bert_mistral.load_pattern("../data/distilbert_mistral/**/events.jsonl", label_extractor= lambda name : name.parent.name)

bert_mistral.add_throughput_column(latency_column = 'latency_ms')

bert_mistral.plot_distributions(column='latency_ms', plot_type='both', bins=15)
bert_mistral.compute_statistics(column="latency_ms")
detect_resource_hogging_normalized(bert_mistral, [solo_bert, solo_mistral])
bert_mistral.compute_statistics(column='latency_ms')
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilbert'
# Added 'throughput' column to dataset 'mistral7b'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# NORMALIZED RESOURCE HOGGING DETECTION (Baseline-Aware)
# ...
# This analysis accounts for different baseline performance of different models.
# Column: latency_ms
# Hogging threshold: 15.0% difference in relative slowdown
# ...

# %% [markdown]
# ## NO MPS

# %%
nomps_2_gpt2 = DataAnalyzer()
nomps_2_gpt2.load_pattern("../data/nomps_pair_distilGPT2/**/events.jsonl", label_extractor= lambda name : name.parent.name)

nomps_2_gpt2.add_throughput_column(latency_column = 'latency_ms')

nomps_2_gpt2.plot_distributions(column='latency_ms', plot_type='both', bins=15)
nomps_2_gpt2.compute_statistics(column="latency_ms")
compute_fairness_metrics(nomps_2_gpt2, metric="median")
detect_resource_hogging_normalized(nomps_2_gpt2, [solo_gpt2])
# Out:
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Loaded 103 samples from events.jsonl with columns: ['type', 'timestamp', 'model_name', 'tag', 'device', 'batch_size', 'seq_len', 'num_iters', 'num_warmup', 'config', 'iter', 'latency_ms', 'avg_ms', 'p50_ms', 'p90_ms', 'p95_ms', 'p99_ms', 'throughput_tokens_per_s', 'tokens_processed', 'sec']
# Added 'throughput' column to dataset 'distilgpt2_1'
# Added 'throughput' column to dataset 'distilgpt2_2'
#
# Throughput computed with: batch_size=8, seq_len=128, tokens_per_batch=1024
# ...
# FAIRNESS ANALYSIS: latency_ms (using median)
# ...
# Number of models: 2
#
# Individual medians:
#   distilgpt2_1        :     6.55 (+9.44% from avg)
#   distilgpt2_2        :     5.42 (-9.44% from avg)
#
# ...
